# %% [markdown]
# # MODFLOW Flopy installation on Google Colab
# Prepared by Harry Lee (https://www2.hawaii.edu/~jonghyun/), Adjusted by Lijing Wang (lijing.wang@uconn.edu, https://lijingwang.github.io/) for ERTH 4735 at University of Connecticut

# %% [markdown]
# ## Install mfpymake: building MODFLOW-based programs from source files.

# %% [markdown]
# We use mfpymake (https://github.com/modflowpy/pymake) USGS' Python package for compiling MODFLOW-based programs.

# %%
# Install python package/module: mfpymake

# !pip install mfpymake==1.2.10
# Out:
# Collecting mfpymake==1.2.10
#   Downloading mfpymake-1.2.10-py3-none-any.whl.metadata (12 kB)
# Requirement already satisfied: numpy in /opt/anaconda3/envs/watershed_workflow_Nov2025/lib/python3.12/site-packages (from mfpymake==1.2.10) (2.3.4)
# Requirement already satisfied: requests in /opt/anaconda3/envs/watershed_workflow_Nov2025/lib/python3.12/site-packages (from mfpymake==1.2.10) (2.32.5)
# Requirement already satisfied: networkx in /opt/anaconda3/envs/watershed_workflow_Nov2025/lib/python3.12/site-packages (from mfpymake==1.2.10) (3.5)
# Collecting meson (from mfpymake==1.2.10)
#   Downloading meson-1.10.1-py3-none-any.whl.metadata (1.8 kB)
# Collecting ninja (from mfpymake==1.2.10)
#   Downloading ninja-1.13.0-py3-none-macosx_10_9_universal2.whl.metadata (5.1 kB)
# Collecting pydotplus (from mfpymake==1.2.10)
#   Downloading pydotplus-2.0.2.tar.gz (278 kB)
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: pyparsing>=2.0.1 in /opt/anaconda3/envs/watershed_workflow_Nov2025/lib/python3.12/site-packages (from pydotplus->mfpymake==1.2.10) (3.2.5)
# Requirement already satisfied: charset_normalizer<4,>=2 in /opt/anaconda3/envs/watershed_workflow_Nov2025/lib/python3.12/site-packages (from requests->mfpymake==1.2.10) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /opt/anaconda3/envs/watershed_workflow_Nov2025/lib/python3.12/site-packages (from requests->mfpymake==1.2.10) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/anaconda3/envs/watershed_workflow_Nov2025/lib/python3.12/site-packages (from requests->mfpymake==1.2.10) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/anaconda3/envs/watershed_workflow_Nov2025/lib/python3.12/site-packages (from requests->mfpymake==1.2.10) (2025.10.5)
# Downloading mfpymake-1.2.10-py3-none-any.whl (70 kB)
# Downloading meson-1.10.1-py3-none-any.whl (1.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 15.8 MB/s  0:00:00
# Downloading ninja-1.13.0-py3-none-macosx_10_9_universal2.whl (310 kB)
# Building wheels for collected packages: pydotplus
#   DEPRECATION: Building 'pydotplus' using the legacy setup.py bdist_wheel mechanism, which will be removed in a future version. pip 25.3 will enforce this behaviour change. A possible replacement is to use the standardized build interface by setting the `--use-pep517` option, (possibly combined with `--no-build-isolation`), or adding a `pyproject.toml` file to the source tree of 'pydotplus'. Discussion can be found at https://github.com/pypa/pip/issues/6334
#   Building wheel for pydotplus (setup.py) ... done
#   Created wheel for pydotplus: filename=pydotplus-2.0.2-py3-none-any.whl size=24636 sha256=70c74b205f07c8dd116984adcb4c25853a3f5eeff02074bc68b5b8298fbf6e7e
#   Stored in directory: /Users/lijing.wang/Library/Caches/pip/wheels/77/54/7c/c8077b6151c819495492300386cf9b151a954259d1a658c63b
# Successfully built pydotplus
# Installing collected packages: pydotplus, ninja, meson, mfpymake
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4/4 [mfpymake]3/4 [mfpymake]
# Successfully installed meson-1.10.1 mfpymake-1.2.10 ninja-1.13.0 pydotplus-2.0.2

# %%
import pymake

# %% [markdown]
# Unfortunately, there is an installation issue in Colab with sys.argv (see below in the `previous implementation` section) since pymake version 1.2.0. We need to change sys.argv temporarily (or see below without sys.argv modification)

# %%
import sys

# %%
print(sys.argv)
myargv = sys.argv
# Out:
# ['/opt/anaconda3/envs/watershed_workflow_Nov2025/lib/python3.12/site-packages/ipykernel_launcher.py', '-f', '/Users/lijing.wang/Library/Jupyter/runtime/kernel-b7562d10-5267-4c2c-b446-0396bfdefd83.json']

# %% [markdown]
# Current pymake version checks the arguments when sys.argv[0] contains '.py' to see whether pymake runs in command line. This would cause error when you run this script in Colab notebook.

# %% [markdown]
# We bypass this issue by assigning sys.argv to a dummy string (do not use ".py" or it will produce error) and restore the values later

# %%
sys.argv = ['ipython']

# %% [markdown]
# ## Install MODFLOW 6: the newest version of MODFLOW

# %%
! gfortran --version
# Out:
# zsh:1: command not found: gfortran

# %%
pymake.build_apps('mf6')
# Out:
# downloading...'https://github.com/MODFLOW-USGS/modflow6/releases/download/6.5.0/mf6.5.0_linux.zip'
# .....................................................................
# uncompressing...'temp/mf6.5.0_linux.zip'
# Removing..."temp/mf6.5.0_linux/src/Utilities/Vector/PetscVector.F90"
# Removing..."temp/mf6.5.0_linux/src/Utilities/Matrix/PetscMatrix.F90"
# Removing..."temp/mf6.5.0_linux/src/Solution/PETSc/PetscSolver.F90"
# Removing..."temp/mf6.5.0_linux/src/Solution/PETSc/PetscConvergence.F90"
# Removing..."temp/mf6.5.0_linux/src/Solution/PETSc/PetscImsPreconditioner.F90"
# Removing..."temp/mf6.5.0_linux/src/Distributed/MpiMessageBuilder.f90"
# Removing..."temp/mf6.5.0_linux/src/Distributed/MpiRouter.f90"
# Removing..."temp/mf6.5.0_linux/src/Distributed/MpiRunControl.F90"
# Removing..."temp/mf6.5.0_linux/src/Distributed/MpiWorld.f90"
# Removing..."temp/mf6.5.0_linux/src/Solution/ParallelSolution.f90"
# Removing..."temp/mf6.5.0_linux/src/Distributed/MpiUnitCache.f90"
# Removing..."temp/mf6.5.0_linux/src/Distributed/MpiMessageCache.f90"
# compiling...mf6
#
# Compiling object files for 'mf6'
# gfortran -O2 -fbacktrace -D__APPLE__ -fall-intrinsics -Wtabs -Wline-truncation -Wunused-label -Wunused-variable -pedantic -std=f2008 -Wcharacter-truncation -I./obj_mf6 -J./mod_mf6 -c src_mf6/Utilities/Libraries/rcm/rcm.f90 -o ./obj_mf6/rcm.o
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 pymake.build_apps('mf6')
#
# File /opt/anaconda3/envs/watershed_workflow_Nov2025/lib/python3.12/site-packages/pymake/pymake_build_apps.py:246, in build_apps(targets, pymake_object, download_dir, appdir, verbose, double, meson, mesondir, clean)
#     244 # build the code
#     245 if build_target:
# --> 246     pmobj.build(modify_exe_name=update_target_name)
#     247 # add target to build_targets list, if necessary
#     248 else:
#     249     pmobj.update_build_targets()
#
# File /opt/anaconda3/envs/watershed_workflow_Nov2025/lib/python3.12/site-packages/pymake/pymake.py:814, in Pymake.build(self, target, srcdir, modify_exe_name)
#     811     print(f"compiling...{self.target}")
#     813     # build the target
# --> 814     self.returncode = main(
#     815         srcdir=self.srcdir,
#     816         target=self.target,
#     817         fc=self.fc,
#     818         cc=self.cc,
#     819         makeclean=self.makeclean,
#     820         expedite=self.expedite,
#     821         dryrun=self.dryrun,
#     822         double=self.double,
#     823         debug=self.debug,
#     824         include_subdirs=self.include_subdirs,
#     825         fflags=self.fflags,
#     826         cflags=self.cflags,
#     827         syslibs=self.syslibs,
#     828         arch=self.arch,
#     829         makefile=self.makefile,
#     830         makefiledir=self.makefiledir,
#     831         srcdir2=self.srcdir2,
#     832         extrafiles=self.extrafiles,
#     833         excludefiles=self.excludefiles,
#     834         sharedobject=self.sharedobject,
#     835         appdir=self.appdir,
#     836         verbose=self.verbose,
#     837         inplace=self.inplace,
#     838         networkx=self.networkx,
#     839         meson=self.meson,
#     840         mesondir=self.mesondir,
#     841     )
#     843 # issue error if target was not built
#     844 if self.returncode != 0:
#
# File /opt/anaconda3/envs/watershed_workflow_Nov2025/lib/python3.12/site-packages/pymake/pymake_base.py:310, in main(srcdir, target, fc, cc, makeclean, expedite, dryrun, double, debug, include_subdirs, fflags, cflags, syslibs, arch, makefile, makefiledir, srcdir2, extrafiles, excludefiles, sharedobject, appdir, verbose, inplace, networkx, meson, mesondir)
#     292     returncode = _meson_build(
#     293         target,
#     294         srcdir,
#    (...)    307         verbose,
#     308     )
#     309 else:
# --> 310     returncode = _pymake_compile(
#     311         srcfiles,
#     312         target,
#     313         fc,
#     314         cc,
#     315         expedite,
#     316         dryrun,
#     317         double,
#     318         debug,
#     319         fflags,
#     320         cflags,
#     321         syslibs,
#     322         arch,
#     323         intelwin,
#     324         sharedobject,
#     325         verbose,
#     326     )
#     328 # create makefile
#     329 if makefile:
#
# File /opt/anaconda3/envs/watershed_workflow_Nov2025/lib/python3.12/site-packages/pymake/pymake_base.py:1076, in _pymake_compile(srcfiles, target, fc, cc, expedite, dryrun, double, debug, fflags, cflags, syslibs, arch, intelwin, sharedobject, verbose)
#    1073 _process_Popen_command(False, cmdlist)
#    1075 # run the command using Popen
# -> 1076 proc = _process_Popen_initialize(cmdlist, intelwin)
#    1078 # write batch file execution to terminal
#    1079 if intelwin:
#
# File /opt/anaconda3/envs/watershed_workflow_Nov2025/lib/python3.12/site-packages/pymake/utils/_Popen_wrapper.py:33, in _process_Popen_initialize(cmdlist, intelwin, cwd)
#      30 else:
#      31     stderr = PIPE
# ---> 33 return Popen(cmdlist, stdout=PIPE, stderr=stderr, cwd=cwd)
#
# File /opt/anaconda3/envs/watershed_workflow_Nov2025/lib/python3.12/subprocess.py:1026, in Popen.__init__(self, args, bufsize, executable, stdin, stdout, stderr, preexec_fn, close_fds, shell, cwd, env, universal_newlines, startupinfo, creationflags, restore_signals, start_new_session, pass_fds, user, group, extra_groups, encoding, errors, text, umask, pipesize, process_group)
#    1022         if self.text_mode:
#    1023             self.stderr = io.TextIOWrapper(self.stderr,
#    1024                     encoding=encoding, errors=errors)
# -> 1026     self._execute_child(args, executable, preexec_fn, close_fds,
#    1027                         pass_fds, cwd, env,
#    1028                         startupinfo, creationflags, shell,
#    1029                         p2cread, p2cwrite,
#    1030                         c2pread, c2pwrite,
#    1031                         errread, errwrite,
#    1032                         restore_signals,
#    1033                         gid, gids, uid, umask,
#    1034                         start_new_session, process_group)
#    1035 except:
#    1036     # Cleanup if the child failed starting.
#    1037     for f in filter(None, (self.stdin, self.stdout, self.stderr)):
#
# File /opt/anaconda3/envs/watershed_workflow_Nov2025/lib/python3.12/subprocess.py:1955, in Popen._execute_child(self, args, executable, preexec_fn, close_fds, pass_fds, cwd, env, startupinfo, creationflags, shell, p2cread, p2cwrite, c2pread, c2pwrite, errread, errwrite, restore_signals, gid, gids, uid, umask, start_new_session, process_group)
#    1953     err_msg = os.strerror(errno_num)
#    1954 if err_filename is not None:
# -> 1955     raise child_exception_type(errno_num, err_msg, err_filename)
#    1956 else:
#    1957     raise child_exception_type(errno_num, err_msg)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'gfortran'

# %% [markdown]
# reset `sys.argv`

# %%
sys.argv = myargv
print(sys.argv)
# Out:
# ['/usr/local/lib/python3.12/dist-packages/colab_kernel_launcher.py', '-f', '/root/.local/share/jupyter/runtime/kernel-1e1784a3-38b4-43cb-b9ce-e12e4a082bde.json']

# %% [markdown]
# check if we have successfully installed MODFLOW 6

# %%
# !ls -al
# Out:
# total 11064
# drwxr-xr-x 1 root root     4096 Nov  7 21:01 .
# drwxr-xr-x 1 root root     4096 Nov  7 20:56 ..
# drwxr-xr-x 4 root root     4096 Nov  5 14:33 .config
# -rwxr-xr-x 1 root root 11308056 Nov  7 21:01 mf6
# drwxr-xr-x 1 root root     4096 Nov  5 14:33 sample_data
# drwxr-xr-x 2 root root     4096 Nov  7 21:01 temp

# %% [markdown]
# Now we run mf6 - we just run mf6 without inputs and you need to stop instruction

# %%
# run modflow 6

# !./mf6 # of course mf6 waits for your inputs since we didn't provide NAM file. Ctrl + M I to stop/interrupt instruction
# Out:
# ERROR REPORT:
#
#   1. mf6: mfsim.nam is not present in working directory.

# %% [markdown]
# if `!./mf6` was not working, it is probably due to permission problem. Change the permission as below:

# %%
# !chmod 755 mf6

# %% [markdown]
# Copy your executable to relevant locations. You can copy it to /usr/local/bin/ use it without specifying its full location (/usr/local/bin/mf6) because /usr/local/bin/ is in the PATH

# %%
# !cp ./mf6 /usr/local/bin

# %%
# run modflow 6
# !mf6 # stop this again
# Out:
# ERROR REPORT:
#
#   1. mf6: mfsim.nam is not present in working directory.

# %% [markdown]
# The name of resulting executable is "mf6" so please use this executable for MODFLOW 6 Flopy applications.
# You may want to copy "mf6" to your drive otherwise you need to compile mf6 everytime you restart the runtime.

# %% [markdown]
# ## Copy MODFLOW 6 to our google drive folder

# %%
from google.colab import drive
drive.mount('/content/drive') # check that: See, edit, create, and delete all of your Google Drive files
# Out:
# Mounted at /content/drive

# %%
# !cp ./mf6 /content/drive/MyDrive

# %% [markdown]
# For further information please visit mfpymake's documentation https://mfpymake.readthedocs.io/en/latest/

# %%
# !ls -al /content/drive/MyDrive/mf6
# Out:
# -rw------- 1 root root 11308056 Nov  7 21:03 /content/drive/MyDrive/mf6

# %%
# !chmod 755 /content/drive/MyDrive/mf6

# %%
# !ls -al /content/drive/MyDrive/mf6
# Out:
# -rwx------ 1 root root 11308056 Nov  7 21:03 /content/drive/MyDrive/mf6

# %%
# run modflow 6
# !/content/drive/MyDrive/mf6
# Out:
# ERROR REPORT:
#
#   1. mf6: mfsim.nam is not present in working directory.
